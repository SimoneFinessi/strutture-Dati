# %% [markdown]
# <a href="https://colab.research.google.com/github/SimoneFinessi/Python/blob/main/esercizzi_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
movie = pd.read_csv('https://gist.githubusercontent.com/tiangechen/b68782efa49a16edaf07dc2cdaa855ea/raw/0c794a9717f18b094eabab2cd6a6b9a226903577/movies.csv')
movie.head()
# Out:
#                                  Film    Genre            Lead Studio  \
# 0          Zack and Miri Make a Porno  Romance  The Weinstein Company
# 1                     Youth in Revolt   Comedy  The Weinstein Company
# 2  You Will Meet a Tall Dark Stranger   Comedy            Independent
# 3                        When in Rome   Comedy                 Disney
# 4               What Happens in Vegas   Comedy                    Fox
#
#    Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  Year
# 0                70       1.747542                 64         $41.94   2008
# 1                52       1.090000                 68         $19.62   2010
# 2                35       1.211818                 43         $26.66   2010
# 3                44       0.000000                 15         $43.04   2010
# 4                72       6.267647                 28        $219.37   2008

# %%
movie.tail(8)
# Out:
#                     Film    Genre  Lead Studio  Audience score %  \
# 69             Enchanted   Comedy       Disney                80
# 70             Dear John    Drama         Sony                66
# 71             Beginners   Comedy  Independent                80
# 72   Across the Universe  romance  Independent                84
# 73         A Serious Man    Drama    Universal                64
# 74    A Dangerous Method    Drama  Independent                89
# 75            27 Dresses   Comedy          Fox                71
# 76  (500) Days of Summer   comedy          Fox                81
#
#     Profitability  Rotten Tomatoes % Worldwide Gross  Year
# 69       4.005737                 93        $340.49   2007
# 70       4.598800                 29        $114.97   2010
# 71       4.471875                 84         $14.31   2011
# 72       0.652603                 54         $29.37   2007
# 73       4.382857                 89         $30.68   2009
# ...

# %%
movie[["Film","Genre"]]
# Out:
#                                   Film    Genre
# 0           Zack and Miri Make a Porno  Romance
# 1                      Youth in Revolt   Comedy
# 2   You Will Meet a Tall Dark Stranger   Comedy
# 3                         When in Rome   Comedy
# 4                What Happens in Vegas   Comedy
# ..                                 ...      ...
# 72                 Across the Universe  romance
# 73                       A Serious Man    Drama
# 74                  A Dangerous Method    Drama
# 75                          27 Dresses   Comedy
# 76                (500) Days of Summer   comedy
#
# [77 rows x 2 columns]

# %%
movie[20:31]
# Out:
#                                    Film      Genre   Lead Studio  \
# 20  The Curious Case of Benjamin Button    Fantasy  Warner Bros.
# 21                     The Back-up Plan     Comedy           CBS
# 22                              Tangled  Animation        Disney
# 23                   Something Borrowed    Romance   Independent
# 24               She's Out of My League     Comedy     Paramount
# 25                 Sex and the City Two     Comedy  Warner Bros.
# 26                   Sex and the City 2     Comedy  Warner Bros.
# 27                     Sex and the City     Comedy  Warner Bros.
# 28                          Remember Me      Drama        Summit
# 29               Rachel Getting Married      Drama   Independent
# 30                             Penelope     Comedy        Summit
#
#     Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  Year
# 20                81       1.783944                 73        $285.43   2008
# ...

# %%
movie['Genre']
# Out:
# 0     Romance
# 1      Comedy
# 2      Comedy
# 3      Comedy
# 4      Comedy
#        ...
# 72    romance
# 73      Drama
# 74      Drama
# 75     Comedy
# 76     comedy
# Name: Genre, Length: 77, dtype: object

# %%
movie[(movie.index==23)|(movie.index==29)|(movie.index==45)][["Film","Year"]]
# Out:
#                       Film  Year
# 23      Something Borrowed  2011
# 29  Rachel Getting Married  2008
# 45              Mamma Mia!  2008

# %%
movie.iloc[[23,29,45]][["Film","Year"]]
# Out:
#                       Film  Year
# 23      Something Borrowed  2011
# 29  Rachel Getting Married  2008
# 45              Mamma Mia!  2008

# %%
movie[movie["Genre"]=="Animation"]["Film"]
# Out:
# 6                WALL-E
# 22              Tangled
# 64    Gnomeo and Juliet
# 65    Gnomeo and Juliet
# Name: Film, dtype: object

# %%
movie[movie.Genre.isin(["Animation"])]["Film"]#isin si usa quando si hanno piu condizioni
# Out:
# 6                WALL-E
# 22              Tangled
# 64    Gnomeo and Juliet
# 65    Gnomeo and Juliet
# Name: Film, dtype: object

# %%
movie[(movie["Lead Studio"]=="Disney")| (movie["Lead Studio"]=="20th Century Fox")]
# Out:
#                                   Film      Genre       Lead Studio  \
# 3                         When in Rome     Comedy            Disney
# 5                  Water For Elephants      Drama  20th Century Fox
# 6                               WALL-E  Animation            Disney
# 16                        The Proposal     Comedy            Disney
# 22                             Tangled  Animation            Disney
# 41                         Monte Carlo    Romance  20th Century Fox
# 60  High School Musical 3: Senior Year     Comedy            Disney
# 64                   Gnomeo and Juliet  Animation            Disney
# 65                   Gnomeo and Juliet  Animation            Disney
# 69                           Enchanted     Comedy            Disney
#
#     Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  Year
# 3                 44       0.000000                 15         $43.04   2010
# ...

# %%
movie[movie["Lead Studio"].isin(["Disney","20th Century Fox"])]#se si ha un nome con uno spazio lo si mette nelle parentesi quadre
# Out:
#                                   Film      Genre       Lead Studio  \
# 3                         When in Rome     Comedy            Disney
# 5                  Water For Elephants      Drama  20th Century Fox
# 6                               WALL-E  Animation            Disney
# 16                        The Proposal     Comedy            Disney
# 22                             Tangled  Animation            Disney
# 41                         Monte Carlo    Romance  20th Century Fox
# 60  High School Musical 3: Senior Year     Comedy            Disney
# 64                   Gnomeo and Juliet  Animation            Disney
# 65                   Gnomeo and Juliet  Animation            Disney
# 69                           Enchanted     Comedy            Disney
#
#     Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  Year
# 3                 44       0.000000                 15         $43.04   2010
# ...

# %%
movie[(movie["Year"]>=2005)&(movie["Year"]<=2010)][["Film","Year"]]
# Out:
#                                   Film  Year
# 0           Zack and Miri Make a Porno  2008
# 1                      Youth in Revolt  2010
# 2   You Will Meet a Tall Dark Stranger  2010
# 3                         When in Rome  2010
# 4                What Happens in Vegas  2008
# ..                                 ...   ...
# 70                           Dear John  2010
# 72                 Across the Universe  2007
# 73                       A Serious Man  2009
# 75                          27 Dresses  2008
# 76                (500) Days of Summer  2009
#
# [63 rows x 2 columns]

# %%
movie[movie["Genre"]=="Drama"]["Audience score %"].mean()
# Out:
# 67.23076923076923

# %%
movie["Audience score %"]=movie["Audience score %"]-((movie["Audience score %"]/100)*10)

movie.head()
# Out:
#                                  Film    Genre            Lead Studio  \
# 0          Zack and Miri Make a Porno  Romance  The Weinstein Company
# 1                     Youth in Revolt   Comedy  The Weinstein Company
# 2  You Will Meet a Tall Dark Stranger   Comedy            Independent
# 3                        When in Rome   Comedy                 Disney
# 4               What Happens in Vegas   Comedy                    Fox
#
#    Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  Year
# 0              63.0       1.747542                 64         $41.94   2008
# 1              46.8       1.090000                 68         $19.62   2010
# 2              31.5       1.211818                 43         $26.66   2010
# 3              39.6       0.000000                 15         $43.04   2010
# 4              64.8       6.267647                 28        $219.37   2008

# %%
movie["Audience score %"]=movie["Audience score %"]*0.9

# %%
movie

# %% [markdown]
# FILA B

# %%
movie.head(12)

# %%
movie.iloc[:,3:7]
# Out:
#     Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross
# 0               63.0       1.747542                 64         $41.94
# 1               46.8       1.090000                 68         $19.62
# 2               31.5       1.211818                 43         $26.66
# 3               39.6       0.000000                 15         $43.04
# 4               64.8       6.267647                 28        $219.37
# ..               ...            ...                ...             ...
# 72              75.6       0.652603                 54         $29.37
# 73              57.6       4.382857                 89         $30.68
# 74              80.1       0.448645                 79          $8.97
# 75              63.9       5.343622                 40        $160.31
# 76              72.9       8.096000                 87         $60.72
#
# [77 rows x 4 columns]

# %%
movie.iloc[10:14]
# Out:
#                                    Film    Genre  Lead Studio  \
# 10  Tyler Perry's Why Did I get Married  Romance  Independent
# 11              Twilight: Breaking Dawn  Romance  Independent
# 12                             Twilight  Romance       Summit
# 13                       The Ugly Truth   Comedy  Independent
#
#     Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  Year
# 10              42.3       3.724192                 46         $55.86   2007
# 11              61.2       6.383364                 26        $702.17   2011
# 12              73.8      10.180027                 49        $376.66   2008
# 13              61.2       5.402632                 14        $205.30   2009

# %%
movie.iloc[10:21][["Lead Studio","Genre"]]
# Out:
#      Lead Studio    Genre
# 10   Independent  Romance
# 11   Independent  Romance
# 12        Summit  Romance
# 13   Independent   Comedy
# 14        Summit    Drama
# 15     Paramount    Drama
# 16        Disney   Comedy
# 17  Warner Bros.   Comedy
# 18     Paramount   Comedy
# 19     Paramount    Drama
# 20  Warner Bros.  Fantasy

# %%
movie[movie["Film"]=="When in Rome"]
# Out:
#            Film   Genre Lead Studio  Audience score %  Profitability  \
# 3  When in Rome  Comedy      Disney                44            0.0
#
#    Rotten Tomatoes % Worldwide Gross  Year
# 3                 15         $43.04   2010

# %%
movie[(movie["Film"]=="When in Rome") |(movie["Film"]=="Waitress")|(movie["Film"]=="WALL-E")]
# Out:
#            Film      Genre  Lead Studio  Audience score %  Profitability  \
# 3  When in Rome     Comedy       Disney                44       0.000000
# 6        WALL-E  Animation       Disney                89       2.896019
# 7      Waitress    Romance  Independent                67      11.089742
#
#    Rotten Tomatoes % Worldwide Gross  Year
# 3                 15         $43.04   2010
# 6                 96        $521.28   2008
# 7                 89         $22.18   2007

# %%
movie[(movie["Rotten Tomatoes %"]>80)&(movie["Rotten Tomatoes %"]<90)]["Film"]
# Out:
# 7                   Waitress
# 22                   Tangled
# 29    Rachel Getting Married
# 39      My Week with Marilyn
# 57                 Jane Eyre
# 71                 Beginners
# 73             A Serious Man
# 76      (500) Days of Summer
# Name: Film, dtype: object

# %%
movie["Rotten Tomatoes %"].max()
# Out:
# 96

# %%
movie["Rotten Tomatoes %"]=movie["Rotten Tomatoes %"]+((movie["Rotten Tomatoes %"]/100)*10)
