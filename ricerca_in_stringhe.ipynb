# %% [markdown]
# <a href="https://colab.research.google.com/github/SimoneFinessi/Python/blob/main/ricerca_in_stringhe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
movie = pd.read_csv('https://gist.githubusercontent.com/tiangechen/b68782efa49a16edaf07dc2cdaa855ea/raw/0c794a9717f18b094eabab2cd6a6b9a226903577/movies.csv')
movie.head()
# Out:
#                                  Film    Genre            Lead Studio  \
# 0          Zack and Miri Make a Porno  Romance  The Weinstein Company
# 1                     Youth in Revolt   Comedy  The Weinstein Company
# 2  You Will Meet a Tall Dark Stranger   Comedy            Independent
# 3                        When in Rome   Comedy                 Disney
# 4               What Happens in Vegas   Comedy                    Fox
#
#    Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  Year
# 0                70       1.747542                 64         $41.94   2008
# 1                52       1.090000                 68         $19.62   2010
# 2                35       1.211818                 43         $26.66   2010
# 3                44       0.000000                 15         $43.04   2010
# 4                72       6.267647                 28        $219.37   2008

# %%
movie[movie["Film"].str.contains("the")]["Film"]#trovare una parola in una Stringa
# Out:
# 25    Sex and the City Two
# 26      Sex and the City 2
# 27        Sex and the City
# 49      Love & Other Drugs
# 63      Going the Distance
# 72     Across the Universe
# Name: Film, dtype: object

# %%
movie[movie["Film"].str.endswith("on")] #visualizzare i film che finiscono con on

# %%
movie[movie["Film"].str.startswith("T")] #visualizzare i film che iniziano con T

# %%
movie.sort_values(by=["Film"])#visualizzare in ordine alfabetico i Film

# %%
movie.sort_values(by=["Film"],ascending=False)#visualizzare in ordine decrescente i Film

# %% [markdown]
# ascending e preimpostato su true quidni per afrloa l contrario si imposta False

# %% [markdown]
# ordinare prima sul genere e poi sul nome del film

# %%
movie.sort_values(by=["Genre","Film"],ascending=True)
# Out:
#                           Film      Genre            Lead Studio  \
# 55                     Killers     Action              Lionsgate
# 64           Gnomeo and Juliet  Animation                 Disney
# 65           Gnomeo and Juliet  Animation                 Disney
# 22                     Tangled  Animation                 Disney
# 6                       WALL-E  Animation                 Disney
# ..                         ...        ...                    ...
# 7                     Waitress    Romance            Independent
# 0   Zack and Miri Make a Porno    Romance  The Weinstein Company
# 43           Midnight in Paris    Romence                   Sony
# 76        (500) Days of Summer     comedy                    Fox
# 72         Across the Universe    romance            Independent
#
#     Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  Year
# 55                45       1.245333                 11         $93.40   2010
# ...
